# %% [markdown]
# # Pandas-1

# %%
# import Python Libraries

# %%
import numpy as np
import pandas as pd

# %%
#read CSV file

# %%
claimants=pd.read_csv("Database/claimants.csv")

# %%
claimants
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0           5         0     0.0       1.0       0.0    50.0  34.940
# 1           3         1     1.0       0.0       0.0    18.0   0.891
# 2          66         1     0.0       1.0       0.0     5.0   0.330
# 3          70         0     0.0       1.0       1.0    31.0   0.037
# 4          96         1     0.0       1.0       0.0    30.0   0.038
# ...       ...       ...     ...       ...       ...     ...     ...
# 1335    34100         1     0.0       1.0       0.0     NaN   0.576
# 1336    34110         0     1.0       1.0       0.0    46.0   3.705
# 1337    34113         1     1.0       1.0       0.0    39.0   0.099
# 1338    34145         0     1.0       0.0       0.0     8.0   3.177
# 1339    34153         1     1.0       1.0       0.0    30.0   0.688
#
# [1340 rows x 7 columns]

# %% [markdown]
# ## Attributes

# %%
claimants.head()
# Out:
#    CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0        5         0     0.0       1.0       0.0    50.0  34.940
# 1        3         1     1.0       0.0       0.0    18.0   0.891
# 2       66         1     0.0       1.0       0.0     5.0   0.330
# 3       70         0     0.0       1.0       1.0    31.0   0.037
# 4       96         1     0.0       1.0       0.0    30.0   0.038

# %%
claimants.tail()
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE   LOSS
# 1335    34100         1     0.0       1.0       0.0     NaN  0.576
# 1336    34110         0     1.0       1.0       0.0    46.0  3.705
# 1337    34113         1     1.0       1.0       0.0    39.0  0.099
# 1338    34145         0     1.0       0.0       0.0     8.0  3.177
# 1339    34153         1     1.0       1.0       0.0    30.0  0.688

# %%
claimants.head(10)
# Out:
#    CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0        5         0     0.0       1.0       0.0    50.0  34.940
# 1        3         1     1.0       0.0       0.0    18.0   0.891
# 2       66         1     0.0       1.0       0.0     5.0   0.330
# 3       70         0     0.0       1.0       1.0    31.0   0.037
# 4       96         1     0.0       1.0       0.0    30.0   0.038
# 5       97         0     1.0       1.0       0.0    35.0   0.309
# 6       10         0     0.0       1.0       0.0     9.0   3.538
# 7       36         0     1.0       1.0       0.0    34.0   4.881
# 8       51         1     1.0       1.0       0.0    60.0   0.874
# 9       55         1     0.0       1.0       0.0     NaN   0.350

# %%
claimants.head(50)
# Out:
#     CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0         5         0     0.0       1.0       0.0    50.0  34.940
# 1         3         1     1.0       0.0       0.0    18.0   0.891
# 2        66         1     0.0       1.0       0.0     5.0   0.330
# 3        70         0     0.0       1.0       1.0    31.0   0.037
# 4        96         1     0.0       1.0       0.0    30.0   0.038
# 5        97         0     1.0       1.0       0.0    35.0   0.309
# 6        10         0     0.0       1.0       0.0     9.0   3.538
# 7        36         0     1.0       1.0       0.0    34.0   4.881
# 8        51         1     1.0       1.0       0.0    60.0   0.874
# 9        55         1     0.0       1.0       0.0     NaN   0.350
# 10       61         0     1.0       1.0       0.0    37.0   6.190
# 11      148         0     0.0       1.0       0.0    41.0  19.610
# 12      150         1     0.0       1.0       0.0     7.0   1.678
# ...

# %%
claimants.tail(50)
# Out:
#       CASENUM  ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 1290    33085         1     0.0       1.0       1.0     NaN   6.100
# 1291    33144         1     1.0       1.0       0.0    19.0   1.537
# 1292    33150         1     0.0       1.0       0.0    10.0   0.964
# 1293    33165         1     0.0       1.0       0.0    40.0   0.749
# 1294    33177         0     1.0       1.0       0.0     NaN   1.041
# 1295    33198         0     1.0       1.0       0.0    18.0   3.180
# 1296    33307         1     0.0       1.0       0.0    36.0   4.448
# 1297    33318         0     0.0       0.0       0.0     NaN   3.800
# 1298    33330         1     1.0       1.0       0.0     8.0   1.195
# 1299    33379         1     1.0       1.0       0.0    19.0   7.393
# 1300    33440         0     0.0       1.0       0.0    71.0   1.595
# 1301    33450         1     1.0       1.0       0.0     NaN   0.700
# 1302    33455         1     1.0       1.0       0.0     9.0   0.364
# ...

# %%
claimants.dtypes
# Out:
# CASENUM       int64
# ATTORNEY      int64
# CLMSEX      float64
# CLMINSUR    float64
# SEATBELT    float64
# CLMAGE      float64
# LOSS        float64
# dtype: object

# %%
claimants.columns
# Out:
# Index(['CASENUM', 'ATTORNEY', 'CLMSEX', 'CLMINSUR', 'SEATBELT', 'CLMAGE',
#        'LOSS'],
#       dtype='object')

# %%
claimants.axes
# Out:
# [RangeIndex(start=0, stop=1340, step=1),
#  Index(['CASENUM', 'ATTORNEY', 'CLMSEX', 'CLMINSUR', 'SEATBELT', 'CLMAGE',
#         'LOSS'],
#        dtype='object')]

# %%
claimants.shape
# Out:
# (1340, 7)

# %%
claimants.ndim
# Out:
# 2

# %%
claimants.size
# Out:
# 9380

# %%
claimants.values
# Out:
# array([[5.0000e+00, 0.0000e+00, 0.0000e+00, ..., 0.0000e+00, 5.0000e+01,
#         3.4940e+01],
#        [3.0000e+00, 1.0000e+00, 1.0000e+00, ..., 0.0000e+00, 1.8000e+01,
#         8.9100e-01],
#        [6.6000e+01, 1.0000e+00, 0.0000e+00, ..., 0.0000e+00, 5.0000e+00,
#         3.3000e-01],
#        ...,
#        [3.4113e+04, 1.0000e+00, 1.0000e+00, ..., 0.0000e+00, 3.9000e+01,
#         9.9000e-02],
#        [3.4145e+04, 0.0000e+00, 1.0000e+00, ..., 0.0000e+00, 8.0000e+00,
#         3.1770e+00],
#        [3.4153e+04, 1.0000e+00, 1.0000e+00, ..., 0.0000e+00, 3.0000e+01,
#         6.8800e-01]])

# %% [markdown]
# ## Satistics

# %%
claimants.describe()
# Out:
#             CASENUM     ATTORNEY       CLMSEX     CLMINSUR     SEATBELT  \
# count   1340.000000  1340.000000  1328.000000  1299.000000  1292.000000
# mean   11202.001493     0.488806     0.558735     0.907621     0.017028
# std     9512.750796     0.500061     0.496725     0.289671     0.129425
# min        0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     4177.000000     0.000000     0.000000     1.000000     0.000000
# 50%     8756.500000     0.000000     1.000000     1.000000     0.000000
# 75%    15702.500000     1.000000     1.000000     1.000000     0.000000
# max    34153.000000     1.000000     1.000000     1.000000     1.000000
#
#             CLMAGE         LOSS
# count  1151.000000  1340.000000
# mean     28.414422     3.806307
# std      20.304451    10.636903
# min       0.000000     0.000000
# 25%       9.000000     0.400000
# 50%      30.000000     1.069500
# 75%      43.000000     3.781500
# max      95.000000   173.604000

# %%
claimants.std()
# Out:
# CASENUM     9512.750796
# ATTORNEY       0.500061
# CLMSEX         0.496725
# CLMINSUR       0.289671
# SEATBELT       0.129425
# CLMAGE        20.304451
# LOSS          10.636903
# dtype: float64

# %%
claimants_sub=claimants.head(50)
claimants_sub.mean()
# Out:
# CASENUM     414.62000
# ATTORNEY      0.48000
# CLMSEX        0.44000
# CLMINSUR      0.87500
# SEATBELT      0.02000
# CLMAGE       30.60000
# LOSS          3.54168
# dtype: float64

# %%
claimants.head(50).mean()
# Out:
# CASENUM     414.62000
# ATTORNEY      0.48000
# CLMSEX        0.44000
# CLMINSUR      0.87500
# SEATBELT      0.02000
# CLMAGE       30.60000
# LOSS          3.54168
# dtype: float64

# %%
claimants['CASENUM']
# Out:
# 0           5
# 1           3
# 2          66
# 3          70
# 4          96
#         ...
# 1335    34100
# 1336    34110
# 1337    34113
# 1338    34145
# 1339    34153
# Name: CASENUM, Length: 1340, dtype: int64

# %%
claimants.CASENUM
# Out:
# 0           5
# 1           3
# 2          66
# 3          70
# 4          96
#         ...
# 1335    34100
# 1336    34110
# 1337    34113
# 1338    34145
# 1339    34153
# Name: CASENUM, Length: 1340, dtype: int64

# %%
claimants[['CASENUM']]
# Out:
#       CASENUM
# 0           5
# 1           3
# 2          66
# 3          70
# 4          96
# ...       ...
# 1335    34100
# 1336    34110
# 1337    34113
# 1338    34145
# 1339    34153
#
# [1340 rows x 1 columns]

# %%
claimants.ATTORNEY.describe()
# Out:
# count    1340.000000
# mean        0.488806
# std         0.500061
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: ATTORNEY, dtype: float64

# %%
claimants.ATTORNEY.shape
# Out:
# (1340,)

# %%
claimants.ATTORNEY.mean()
# Out:
# 0.48880597014925375
